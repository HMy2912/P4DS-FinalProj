# %% [markdown]
# ## Introduction
#
# Intro about group and vision or POV

# %% [markdown]
# ## Library
#
# Some library and check the sys ...

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\QuocPhat\\anaconda3\\python.exe'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data Collection
#
# 1. Objectives and Ideas
#
# The subject of our data...
# Our ideas ...
#
# *What subject is your data about?*
#
# 2. Sources
#
# The source/ survey ...
#
# *What is the source of your data?*
#
# 3. License
#
# The license from kaggle ...
#
# *Do authors of this data allow you to use like this? You can check the data license*
#
# 4. Origin
#
# Which method the authors used to collect data?
#
# *How did authors collect data?*

# %% [markdown]
# ## Exploring Data
#
# We will need to check briefly what is in the dataset that we collected ...

# %%
mh_df = pd.read_csv('mental-heath-in-tech-2016_20161114.csv')
mh_df.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %% [markdown]
# We need to change the column name ...

# %%
old_cols = list(mh_df.columns)
renamed_columns = ['self_empl_flag', 'comp_no_empl', 'tech_comp_flag', 'tech_role_flag', 'mh_coverage_flag',
                  'mh_coverage_awareness_flag', 'mh_employer_discussion', 'mh_resources_provided', 'mh_anonimity_flag',
                  'mh_medical_leave', 'mh_discussion_neg_impact', 'ph_discussion_neg_impact', 'mh_discussion_cowork',
                  'mh_discussion_supervis', 'mh_eq_ph_employer', 'mh_conseq_coworkers', 'mh_coverage_flag2', 'mh_online_res_flag',
                  'mh_diagnosed&reveal_clients_flag', 'mh_diagnosed&reveal_clients_impact', 'mh_diagnosed&reveal_cowork_flag', 'mh_cowork_reveal_neg_impact',
                  'mh_prod_impact', 'mh_prod_impact_perc', 'prev_employers_flag', 'prev_mh_benefits', 'prev_mh_benefits_awareness',
                  'prev_mh_discussion', 'prev_mh_resources', 'prev_mh_anonimity', 'prev_mh_discuss_neg_conseq', 'prev_ph_discuss_neg_conseq',
                  'prev_mh_discussion_cowork', 'prev_mh_discussion_supervisor', 'prev_mh_importance_employer', 'prev_mh_conseq_coworkers',
                  'future_ph_specification', 'why/why_not', 'future_mh_specification', 'why/why_not2', 'mh_hurt_on_career', 'mh_neg_view_cowork',
                  'mh_sharing_friends/fam_flag', 'mh_bad_response_workplace', 'mh_for_others_bad_response_workplace', 'mh_family_hist',
                  'mh_disorder_past', 'mh_disorder_current', 'yes:what_diagnosis?', 'maybe:whats_your_diag', 'mh_diagnos_proffesional',
                  'yes:condition_diagnosed', 'mh_sought_proffes_treatm', 'mh_eff_treat_impact_on_work', 'mh_not_eff_treat_impact_on_work',
                  'age', 'sex', 'country_live', 'live_us_teritory', 'country_work', 'work_us_teritory', 'work_position', 'remote_flag']
mh_df.columns = renamed_columns

# %% [markdown]
# ### How many rows and columns in the dataset?

# %%
num_rows, num_cols = len(mh_df), len(mh_df.columns)
num_rows, num_cols
# Out:
# (1433, 63)

# %% [markdown]
# ### What is the meaning of each row?
#
# Each row presents for each respondents ...

# %%
mh_df.head()
# Out:
#    self_empl_flag comp_no_empl  tech_comp_flag  tech_role_flag  \
# 0               0       26-100             1.0             NaN
# 1               0         6-25             1.0             NaN
# 2               0         6-25             1.0             NaN
# 3               1          NaN             NaN             NaN
# 4               0         6-25             0.0             1.0
#
#                   mh_coverage_flag mh_coverage_awareness_flag  \
# 0  Not eligible for coverage / N/A                        NaN
# 1                               No                        Yes
# 2                               No                        NaN
# 3                              NaN                        NaN
# 4                              Yes                        Yes
#
#   mh_employer_discussion mh_resources_provided mh_anonimity_flag  \
# 0                     No                    No      I don't know
# 1                    Yes                   Yes               Yes
# ...

# %% [markdown]
# ### Are there duplicated rows?

# %% [markdown]
# Fortunately, there is NO duplicated rows in the dataset.

# %%
dups_count = mh_df.duplicated(keep='first').sum()
dups_count != 0
# Out:
# False

# %% [markdown]
# ### What is the meaning of each column?
#
# Each column is one question in the survey ...

# %%
meaning_cols = pd.DataFrame({'meaning': old_cols}).set_index(pd.Series(renamed_columns))
meaning_cols
# Out:
#                                                             meaning
# self_empl_flag                               Are you self-employed?
# comp_no_empl      How many employees does your company or organi...
# tech_comp_flag    Is your employer primarily a tech company/orga...
# tech_role_flag    Is your primary role within your company relat...
# mh_coverage_flag  Does your employer provide mental health benef...
# ...                                                             ...
# live_us_teritory         What US state or territory do you live in?
# country_work                           What country do you work in?
# work_us_teritory         What US state or territory do you work in?
# work_position     Which of the following best describes your wor...
# remote_flag                                   Do you work remotely?
#
# [63 rows x 1 columns]

# %% [markdown]
# ### What is the current data type of each column?
# ### Are there columns having inappropriate data types?

# %%
col_dtypes = pd.Series(mh_df.dtypes)
col_dtypes
# Out:
# self_empl_flag        int64
# comp_no_empl         object
# tech_comp_flag      float64
# tech_role_flag      float64
# mh_coverage_flag     object
#                      ...
# live_us_teritory     object
# country_work         object
# work_us_teritory     object
# work_position        object
# remote_flag          object
# Length: 63, dtype: object

# %% [markdown]
# ### What is the percentage of missing values?

# %%
percent_missing = mh_df.isnull().sum() * 100 / len(mh_df)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df
# Out:
#                   percent_missing
# self_empl_flag           0.000000
# comp_no_empl            20.027913
# tech_comp_flag          20.027913
# tech_role_flag          81.646895
# mh_coverage_flag        20.027913
# ...                           ...
# live_us_teritory        41.381717
# country_work             0.000000
# work_us_teritory        40.614096
# work_position            0.000000
# remote_flag              0.000000
#
# [63 rows x 1 columns]

# %% [markdown]
# ### With each numerical column, how are values distributed?
# * Min? max? Are they abnormal?

# %% [markdown]
# ### With each categorical column, how are values distributed?
# * How many different values? Are they abnormal?

# %% [markdown]
# ## Questions
#
# *What is the question? What are benefits of finding the answer?*

# %% [markdown]
# 1. Is having mental health issues harmful to someone's career?

# %% [markdown]
# There are 70 unique genders, which is because participants are allowed to enter their gender freely. I did my best to group the genders while respecting the participants' answers to the best of my ability.

# %%
mh_df['sex'] = mh_df['sex'].replace([
    'male', 'Male ', 'M', 'm', 'man', 'Cis male',
    'Male.', 'Male (cis)', 'Man', 'Sex is male',
    'cis male', 'Malr', 'Dude', "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
    'mail', 'M|', 'male ', 'Cis Male', 'Male (trans, FtM)',
    'cisdude', 'cis man', 'MALE'], 'Male')
mh_df['sex'] = mh_df['sex'].replace([
    'female', 'I identify as female.', 'female ',
    'Female assigned at birth ', 'F', 'Woman', 'fm', 'f',
    'Cis female', 'Transitioned, M2F', 'Female or Multi-Gender Femme',
    'Female ', 'woman', 'female/woman', 'Cisgender Female', 
    'mtf', 'fem', 'Female (props for making this a freeform field, though)',
    ' Female', 'Cis-woman', 'AFAB', 'Transgender woman',
    'Cis female '], 'Female')
mh_df['sex'] = mh_df['sex'].replace([
    'Bigender', 'non-binary,', 'Genderfluid (born female)',
    'Other/Transfeminine', 'Androgynous', 'male 9:1 female, roughly',
    'nb masculine', 'genderqueer', 'Human', 'Genderfluid',
    'Enby', 'genderqueer woman', 'Queer', 'Agender', 'Fluid',
    'Genderflux demi-girl', 'female-bodied; no feelings about gender',
    'non-binary', 'Male/genderqueer', 'Nonbinary', 'Other', 'none of your business',
    'Unicorn', 'human', 'Genderqueer'], 'Genderqueer/Other')

# replace the one null with Male, the mode gender, so we don't have to drop the row
mh_df['sex'] = mh_df['sex'].replace(np.NaN, 'Male')
mh_df['sex'].unique()
# Out:
# array(['Male', 'Female', 'Genderqueer/Other'], dtype=object)

# %% [markdown]
# - The majority of survey respondents believe that being identified as a person with a mental health problem will harm their career.
# - This shows that a lot of people have an understanding of mental health, a lot of people think it's really bad for their work. But, there are also some people who disagree with that and say that it doesn't in fact harm their career.
# - Based on the graph, we can see that the percentage of women who choose "Yes" is more than the percentage of men who choose "yes", so it is possible that women feel the harmful effects of mental health more than men.

# %%
g = sns.countplot(y='mh_hurt_on_career',
                 hue='sex', data=mh_df, 
                  order=['Yes, it has', 'Yes, I think it would',
                        'No, it has not', "No, I don't think it would", 'Maybe'])
plt.title('Number of People who Believe Identifying as a Person\nwith a Mental Health Issue is Harmful to Career')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Gender')
plt.ylabel('Number of Responses')
plt.show()

# %% [markdown]
# 2. Given a person's knowledge of his/ her own mentak health, what kind of company should he/ she work at to be comfortable when asking help?

# %% [markdown]
# - About 3/4 of the survey respondents work in a technology company or have a tech role in a non-tech company.
# - So the majority of participants are in the technology sector. So we only consider 2 types of companies that are tech company and non-tech campany

# %%
labels = ['Self-employed', 'Works at tech company', 'Has a tech role in non-tech company', 'Has a non-tech role at a non-tech company']
sizes = [mh_df['self_empl_flag'].value_counts()[1],
         mh_df['tech_comp_flag'].value_counts()[1],
         mh_df['tech_role_flag'].value_counts()[1],
         mh_df['tech_role_flag'].value_counts()[0]
        ]
# print(sizes) # adds up to 1433, which is the total number of participants
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
data_tech=mh_df[mh_df['tech_comp_flag']==1]
data_non_tech=mh_df[mh_df['tech_role_flag']==1]

# %%
fig, ax = plt.subplots(figsize = (16, 12), ncols=2, nrows=4)
plt.subplots_adjust(left=0.125, right=0.9, bottom=0.1, top = 0.9, wspace=0, hspace = 0.3)
plt.suptitle('What kind of company should he/ she work at to be comfortable when asking help', fontsize = 25, y = 1)

all_ = data_tech['mh_coverage_flag'].count()
no_ = data_tech[data_tech['mh_coverage_flag'] == 'No']['mh_coverage_flag'].count()
yes_ = data_tech[data_tech['mh_coverage_flag'] == 'Yes']['mh_coverage_flag'].count()
not_know_ = data_tech[data_tech['mh_coverage_flag'] == "I don't know"]['mh_coverage_flag'].count()
not_elig_ = data_tech[data_tech['mh_coverage_flag'] == 'Not eligible for coverage / N/A']['mh_coverage_flag'].count()

labels = 'No', 'Yes', 'Not Know', 'Not Elig.'
sizes = [no_/all_, yes_/all_, not_know_/all_, not_elig_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3']
explode = (0, 0.03, 0, 0)  # explode 1st slice

ax[0][0].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[0][0].axis('equal')
ax[0][0].set_title('MH Coverage Provided', pad = 14, fontsize = 18)


all_ = data_non_tech['mh_coverage_flag'].count()
no_ = data_non_tech[data_non_tech['mh_coverage_flag'] == 'No']['mh_coverage_flag'].count()
yes_ = data_non_tech[data_non_tech['mh_coverage_flag'] == 'Yes']['mh_coverage_flag'].count()
not_know_ = data_non_tech[data_non_tech['mh_coverage_flag'] == "I don't know"]['mh_coverage_flag'].count()
not_elig_ = data_non_tech[data_non_tech['mh_coverage_flag'] == 'Not eligible for coverage / N/A']['mh_coverage_flag'].count()

labels = 'No', 'Yes', 'Not Know', 'Not Elig.'
sizes = [no_/all_, yes_/all_, not_know_/all_, not_elig_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3']
explode = (0, 0.03, 0, 0)  # explode 1st slice

ax[0][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[0][1].axis('equal')
ax[0][1].set_title('MH Coverage Provided', pad = 14, fontsize = 18)


all_ = data_tech['mh_resources_provided'].count()
no_ = data_tech[data_tech['mh_resources_provided'] == 'No']['mh_resources_provided'].count()
yes_ = data_tech[data_tech['mh_resources_provided'] == 'Yes']['mh_resources_provided'].count()
not_know_ = data_tech[data_tech['mh_resources_provided'] == "I don't know"]['mh_resources_provided'].count()

labels = 'No', 'Yes', 'Not Know'
sizes = [no_/all_, yes_/all_, not_know_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
explode = (0, 0.03, 0)  # explode 1st slice

ax[1][0].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[1][0].axis('equal')
ax[1][0].set_title('MH Resources Provided', pad = 14, fontsize = 18)



all_ = data_non_tech['mh_resources_provided'].count()
no_ = data_non_tech[data_non_tech['mh_resources_provided'] == 'No']['mh_resources_provided'].count()
yes_ = data_non_tech[data_non_tech['mh_resources_provided'] == 'Yes']['mh_resources_provided'].count()
not_know_ = data_non_tech[data_non_tech['mh_resources_provided'] == "I don't know"]['mh_resources_provided'].count()

labels = 'No', 'Yes', 'Not Know'
sizes = [no_/all_, yes_/all_, not_know_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
explode = (0, 0.03, 0)  # explode 1st slice

ax[1][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[1][1].axis('equal')
ax[1][1].set_title('MH Resources Provided', pad = 14, fontsize = 18)



all_ = data_tech['mh_medical_leave'].count()
v_easy = data_tech[data_tech['mh_medical_leave'] == 'Very easy']['mh_medical_leave'].count()
s_easy= data_tech[data_tech['mh_medical_leave'] == 'Somewhat easy']['mh_medical_leave'].count()
middle= data_tech[data_tech['mh_medical_leave'] == 'Neither easy nor difficult']['mh_medical_leave'].count()
v_hard = data_tech[data_tech['mh_medical_leave'] == "Very difficult"]['mh_medical_leave'].count()
s_hard=data_tech[data_tech['mh_medical_leave'] == "Somewhat difficult"]['mh_medical_leave'].count()
d_know=data_tech[data_tech['mh_medical_leave'] == "I don't know"]['mh_medical_leave'].count()
labels = 'Very easy','Somewhat easy','Middle',"Very hard","Somewhat hard","I don't know"
sizes = [v_easy/all_, s_easy/all_, middle/all_,v_hard/all_,s_hard/all_,d_know/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6', '#F4D03F']
explode = (0, 0.03, 0,0,0,0)  # explode 1st slice

ax[2][0].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[2][0].axis('equal')
ax[2][0].set_title('MH Medical Leave Request', pad = 14, fontsize = 18)


all_ = data_non_tech['mh_medical_leave'].count()
v_easy = data_non_tech[data_non_tech['mh_medical_leave'] == 'Very easy']['mh_medical_leave'].count()
s_easy= data_non_tech[data_non_tech['mh_medical_leave'] == 'Somewhat easy']['mh_medical_leave'].count()
middle= data_non_tech[data_non_tech['mh_medical_leave'] == 'Neither easy nor difficult']['mh_medical_leave'].count()
v_hard = data_non_tech[data_non_tech['mh_medical_leave'] == "Very difficult"]['mh_medical_leave'].count()
s_hard=data_non_tech[data_non_tech['mh_medical_leave'] == "Somewhat difficult"]['mh_medical_leave'].count()
d_know=data_non_tech[data_non_tech['mh_medical_leave'] == "I don't know"]['mh_medical_leave'].count()
labels = 'Very easy','Somewhat easy','Middle',"Very hard","Somewhat hard","I don't know"
sizes = [v_easy/all_, s_easy/all_, middle/all_,v_hard/all_,s_hard/all_,d_know/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6', '#F4D03F']
explode = (0, 0.03, 0,0,0,0)  # explode 1st slice

ax[2][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[2][1].axis('equal')
ax[2][1].set_title('MH Medical Leave Request', pad = 14, fontsize = 18)


all_ = data_tech['mh_eq_ph_employer'].count()
no_ = data_tech[data_tech['mh_eq_ph_employer'] == 'No']['mh_eq_ph_employer'].count()
yes_ = data_tech[data_tech['mh_eq_ph_employer'] == 'Yes']['mh_eq_ph_employer'].count()
not_know_ = data_tech[data_tech['mh_eq_ph_employer'] == "I don't know"]['mh_eq_ph_employer'].count()

labels = 'No', 'Yes', 'Not Know'
sizes = [no_/all_, yes_/all_, not_know_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
explode = (0, 0.03, 0)  # explode 1st slice

ax[3][0].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[3][0].axis('equal')
ax[3][0].set_title('Mental & Physical Health Equal Importance', pad = 14, fontsize = 18)



all_ = data_non_tech['mh_eq_ph_employer'].count()
no_ = data_non_tech[data_non_tech['mh_eq_ph_employer'] == 'No']['mh_eq_ph_employer'].count()
yes_ = data_non_tech[data_non_tech['mh_eq_ph_employer'] == 'Yes']['mh_eq_ph_employer'].count()
not_know_ = data_non_tech[data_non_tech['mh_eq_ph_employer'] == "I don't know"]['mh_eq_ph_employer'].count()

labels = 'No', 'Yes', 'Not Know'
sizes = [no_/all_, yes_/all_, not_know_/all_]
colors = ['#7FB3D5', '#73C6B6', '#F0B27A']
explode = (0, 0.03, 0)  # explode 1st slice

ax[3][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
ax[3][1].axis('equal')
ax[3][1].set_title('Mental & Physical Health Equal Importance', pad = 14, fontsize = 18)
# Out:
# <ipython-input-68-a3b8688d9a54>:64: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   ax[1][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
# <ipython-input-68-a3b8688d9a54>:99: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   ax[2][1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
# Text(0.5, 1.0, 'Mental & Physical Health Equal Importance')

# %% [markdown]
# - According to the chart above, both types of companies provide health benefits as part of a health protection system. Thus, companies are concerned with the health of their employees. Non-tech companies provide more resources for employees to learn about mental health than tech companies at 38.7% versus 22.0%. From this, we can see that non-tech companies have taken an interest in understanding the mental health of more employees.
# - But it's easier for technology companies to allow their employees to quit their jobs to treat mental illnesses than non-tech companies. As well as the level of emphasis on mental health as physical health of companies is higher than non-tech companies. If so, technology companies have a very good policy with employees on mental health and make treating those issues a priority.
# - Through the above comments, to have the choice of a company that we will feel most comfortable asking for help, the best choice is a technology company.

# %% [markdown]
# 3. Do the company often take care of the employees' mental health?

# %% [markdown]
# 4. Do the employees mention or discuss about their mental health / mental health issues at work / friends / family?

# %% [markdown]
# ## Reflection
#
# 1. Difficulties
#
# *Each member: What difficulties have you encountered?*
#
# 2. Experiences
#
# *Each member: What have you learned?*
#
# 3. Expansion
#
# *Your group: If you had more time, what would you do?*

# %% [markdown]
# ## References
#
# *list the references*
